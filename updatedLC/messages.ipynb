# %% [markdown]
# ### Messages

# %% [markdown]
# Messages are the fundamental unit of context for models in LangChain. They represent the input and output of models, carrying both the content and metadata needed to represent the state of a conversation when interacting with an LLM. Messages are objects that contain:

# %% [markdown]
# 1. Role - Identifies the message type (e.g. system, user)
# 2. Content - Represents the actual content of the message (like text, images, audio, documents, etc.)
# 3. Metadata - Optional fields such as response information, message IDs, and token usage

# %% [markdown]
# LangChain provides a standard message type that works across all model providers, ensuring consistent behavior regardless of the model being called.

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
model = init_chat_model("groq:llama-3.3-70b-versatile")

# %% [markdown]
# ### Text prompts
# Text prompts are strings - ideal for straightforward generation tasks where you don’t need to retain conversation history.

# %%
model.invoke("what is langchain")
# Out:
# AIMessage(content='LangChain is an open-source framework for building applications that utilize large language models (LLMs). It was created to simplify the process of integrating LLMs into various projects, enabling developers to focus on building applications rather than worrying about the underlying infrastructure.\n\nLangChain provides a set of tools and APIs that allow developers to:\n\n1. **Interface with LLMs**: LangChain supports a wide range of LLMs, including popular models like LLaMA, PaLM, and others. It provides a unified interface for interacting with these models, making it easier to switch between them or use multiple models in a single application.\n2. **Manage memory and caching**: LangChain includes features for managing memory and caching, which can help improve the performance and efficiency of LLM-based applications.\n3. **Implement prompt engineering**: LangChain offers tools and techniques for crafting effective prompts, which is critical for getting the most out of LLMs.\n4. **Build conversational interfaces**: LangChain includes features for building conversational interfaces, such as chatbots, voice assistants, and other types of interactive applications.\n5. **Integrate with other tools and services**: LangChain provides APIs and plugins for integrating with other tools and services, such as databases, messaging platforms, and more.\n\nThe LangChain framework is designed to be flexible and extensible, allowing developers to build a wide range of applications, including:\n\n1. **Chatbots and virtual assistants**\n2. **Language translation and localization tools**\n3. **Text summarization and analysis applications**\n4. **Content generation and writing tools**\n5. **Conversational games and entertainment applications**\n\nBy providing a standardized framework for working with LLMs, LangChain aims to accelerate the development of AI-powered applications and enable more developers to build innovative solutions that leverage the power of large language models.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 370, 'prompt_tokens': 39, 'total_tokens': 409, 'completion_time': 0.992262657, 'completion_tokens_details': None, 'prompt_time': 0.000963528, 'prompt_tokens_details': None, 'queue_time': 0.161562666, 'total_time': 0.993226185}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a0009e-79bb-7b52-b386-78d95db43f91-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 39, 'output_tokens': 370, 'total_tokens': 409})

# %% [markdown]
# Use text prompts when:

# %% [markdown]
# 1. You have a single, standalone request
# 2. You don’t need conversation history
# 3. You want minimal code complexity

# %% [markdown]
# ### Message Prompts

# %% [markdown]
# Alternatively, you can pass in a list of messages to the model by providing a list of message objects.

# %% [markdown]
# Message types
#
# 1. System message - Tells the model how to behave and provide context for interactions
# 2. Human message - Represents user input and interactions with the model
# 3. AI message - Responses generated by the model, including text content, tool calls, and metadata
# 4. Tool message - Represents the outputs of tool calls

# %% [markdown]
# ### System Message

# %% [markdown]
# A SystemMessage represent an initial set of instructions that primes the model’s behavior. You can use a system message to set the tone, define the model’s role, and establish guidelines for responses.

# %% [markdown]
# ### Human Message

# %% [markdown]
# A HumanMessage represents user input and interactions. They can contain text, images, audio, files, and any other amount of multimodal content.

# %% [markdown]
# ### AI Message

# %% [markdown]
# An AIMessage represents the output of a model invocation. They can include multimodal data, tool calls, and provider-specific metadata that you can later access.

# %% [markdown]
# ### Tool Message

# %% [markdown]
# For models that support tool calling, AI messages can contain tool calls. Tool messages are used to pass the results of a single tool execution back to the model.

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage

messages = [
    SystemMessage("You are a poetry expert"),
    HumanMessage("write the poem about friends")
]

response=model.invoke(messages)
response.content
# Out:
# '"Treasured Bonds"\n\nIn laughter and in tears, they stand by my side,\nA constant presence, a love that won\'t subside.\nThrough life\'s joys and its strife, they remain true,\nA shelter from the storm, a friendship shining through.\n\nWith hearts that beat as one, we share our deepest fears,\nAnd in each other\'s eyes, we dry our tears.\nWe\'ve danced under the stars, and sung in the rain,\nTogether we\'ve chased dreams, and made memories that remain.\n\nTheir smiles are contagious, their humor a balm,\nTheir listening ears, a sanctuary from life\'s alarm.\nThey know my quirks and flaws, and yet they still adore,\nThe imperfect me, with all my heart\'s fragile core.\n\nIn times of need, they lend a helping hand,\nA supportive whisper, a comforting stand.\nThey celebrate my wins, and help me through my falls,\nA safety net of love, that catches me through it all.\n\nThrough thick and thin, through every up and down,\nOur bond remains unbroken, a circle of love that\'s found.\nFor in the tapestry of life, our threads are intertwined,\nA beautiful brocade, of friendship\'s precious design.\n\nSo here\'s to my friends, my partners in this ride,\nMy confidants, my soulmates, my heart\'s inside.\nMay our friendship continue, to flourish and to grow,\nA treasure to cherish, a bond that forever glows.'

# %%
systme_msg = SystemMessage("You are a helpful coding assistant")

messages = [
    systme_msg,
    HumanMessage("How do i create the REST API?")
]

response = model.invoke(messages)
print(response.content)
# Out:
# Creating a REST (Representational State of Resource) API involves several steps. Here is a step-by-step guide to help you get started:
#
# 1. **Define the API's purpose and scope**: Determine what functionality your API will provide and what resources it will expose. Identify the target audience and the types of requests they will make.
# 2. **Choose a programming language and framework**: Select a language and framework that you're comfortable with and that supports RESTful API development. Some popular choices include:
# 	* Node.js with Express.js
# 	* Python with Flask or Django
# 	* Java with Spring Boot
# 	* Ruby with Ruby on Rails
# 3. **Design the API's endpoints**: Determine the endpoints (URLs) that your API will expose. Endpoints typically follow a consistent naming convention and use HTTP methods to define the action:
# 	* `GET /users`: Retrieve a list of users
# 	* `GET /users/{id}`: Retrieve a specific user by ID
# 	* `POST /users`: Create a new user
# 	* `PUT /users/{id}`: Update an existing user
# 	* `DELETE /users/{id}`: Delete a user
# 4. **Define the request and response formats**: Choose the data formats for requests and responses. Common formats include:
# 	* JSON (JavaScript Object Notation)
# 	* XML (Extensible Markup Language)
# 	* CSV (Comma Separated Values)
# 5. **Implement authentication and authorization**: Determine how you will authenticate and authorize users to access your API. Common approaches include:
# 	* API keys
# 	* OAuth
# 	* JWT (JSON Web Tokens)
# 6. **Implement the API endpoints**: Write the code for each endpoint, using your chosen language and framework. This typically involves:
# 	* Handling HTTP requests and responses
# 	* Validating and sanitizing input data
# 	* Interacting with a database or other storage system
# 	* Returning data in the desired format
# 7. **Test the API**: Use tools like Postman or cURL to test each endpoint and ensure it behaves as expected.
# 8. **Document the API**: Create documentation for your API, including:
# 	* Endpoint descriptions
# 	* Request and response formats
# 	* Authentication and authorization details
# 	* Error handling and troubleshooting information
#
# Some popular tools and frameworks for building REST APIs include:
#
# * **Express.js**: A Node.js framework for building web applications and REST APIs
# * **Swagger**: A framework for building and documenting REST APIs
# * **Postman**: A tool for testing and exploring REST APIs
# * **API Gateway**: A service provided by cloud providers like AWS, Google Cloud, or Azure for managing and securing REST APIs
#
# Here is an example of a simple REST API in Node.js using Express.js:
# ```javascript
# const express = require('express');
# const app = express();
#
# // Define a route for retrieving users
# app.get('/users', (req, res) => {
#   const users = [
#     { id: 1, name: 'John Doe' },
#     { id: 2, name: 'Jane Doe' }
#   ];
#   res.json(users);
# });
#
# // Define a route for creating a new user
# app.post('/users', (req, res) => {
#   const { name } = req.body;
#   const user = { id: 3, name };
#   res.json(user);
# });
#
# // Start the server
# app.listen(3000, () => {
#   console.log('Server started on port 3000');
# });
# ```
# This example defines two endpoints: `GET /users` and `POST /users`. The `GET` endpoint returns a list of users, while the `POST` endpoint creates a new user. The API uses JSON as the data format for requests and responses.

# %%
from langchain.messages import SystemMessage, HumanMessage

system_msg = SystemMessage("""
You are a senior Python developer with expertise in web frameworks.
Always provide code examples and explain your reasoning.
Be concise but thorough in your explanations.
""")

messages = [
    systme_msg,
    HumanMessage("How to create FAST API")
]

response = model.invoke(messages)
print(response.content)
# Out:
# **Creating a FastAPI Application**
# =====================================
#
# FastAPI is a modern, fast (high-performance), web framework for building APIs with Python 3.7+ based on standard Python type hints. Here's a step-by-step guide to create a FastAPI application:
#
# ### **Prerequisites**
#
# * Python 3.7 or higher
# * pip (Python package installer)
# * A code editor or IDE
#
# ### **Install FastAPI and Required Libraries**
#
# First, install FastAPI and the required libraries using pip:
# ```bash
# pip install fastapi uvicorn
# ```
# * `fastapi`: The FastAPI framework
# * `uvicorn`: An ASGI server that supports FastAPI
#
# ### **Create a New FastAPI Application**
#
# Create a new Python file, e.g., `main.py`, and add the following code:
# ```python
# # main.py
# from fastapi import FastAPI
#
# app = FastAPI()
#
# @app.get("/")
# def read_root():
#     return {"message": "Welcome to my FastAPI application"}
# ```
# This code creates a new FastAPI application with a single endpoint, `/`, that returns a JSON response.
#
# ### **Run the Application**
#
# Run the application using Uvicorn:
# ```bash
# uvicorn main:app --host 0.0.0.0 --port 8000
# ```
# * `main`: The name of the Python file (without the `.py` extension)
# * `app`: The instance of the FastAPI application
# * `--host 0.0.0.0`: Listen on all available network interfaces
# * `--port 8000`: Listen on port 8000
#
# Open a web browser and navigate to `http://localhost:8000/` to see the response.
#
# ### **Add More Endpoints**
#
# Add more endpoints to your application as needed. For example, you can create a new endpoint to handle POST requests:
# ```python
# from fastapi import FastAPI, HTTPException
# from pydantic import BaseModel
#
# app = FastAPI()
#
# class Item(BaseModel):
#     name: str
#     price: float
#
# @app.post("/items/")
# def create_item(item: Item):
#     return item
# ```
# This code defines a new endpoint, `/items/`, that accepts a JSON payload with `name` and `price` fields.
#
# ### **Use a Database (Optional)**
#
# If you need to store data, you can use a database like SQLite or PostgreSQL. For example, you can use the `sqlalchemy` library to connect to a SQLite database:
# ```python
# from fastapi import FastAPI
# from sqlalchemy import create_engine
# from sqlalchemy.orm import sessionmaker
#
# app = FastAPI()
#
# engine = create_engine("sqlite:///example.db")
# Session = sessionmaker(bind=engine)
# session = Session()
# ```
# This code creates a new SQLite database file, `example.db`, and establishes a connection to it.
#
# ### **Example Use Case**
#
# Here's an example use case that demonstrates how to create a simple RESTful API with FastAPI:
# ```python
# from fastapi import FastAPI
# from pydantic import BaseModel
#
# app = FastAPI()
#
# class Item(BaseModel):
#     id: int
#     name: str
#     price: float
#
# items = [
#     {"id": 1, "name": "Item 1", "price": 10.99},
#     {"id": 2, "name": "Item 2", "price": 9.99},
# ]
#
# @app.get("/items/")
# def read_items():
#     return items
#
# @app.get("/items/{item_id}")
# def read_item(item_id: int):
#     for item in items:
#         if item["id"] == item_id:
#             return item
#     raise HTTPException(status_code=404, detail="Item not found")
#
# @app.post("/items/")
# def create_item(item: Item):
#     items.append(item.dict())
#     return item
# ```
# This code defines a simple RESTful API with three endpoints:
#
# * `GET /items/`: Returns a list of all items
# * `GET /items/{item_id}`: Returns a single item by ID
# * `POST /items/`: Creates a new item
#
# You can test this API using tools like `curl` or a REST client like Postman.
#
# ### **Conclusion**
#
# In this guide, we created a simple FastAPI application with multiple endpoints. We also demonstrated how to use a database and handle errors. FastAPI is a powerful and flexible framework that can help you build robust and scalable APIs quickly.

# %%
## Message Metadata
human_msg = HumanMessage(
    content="Hello!",
    name="alice",  # Optional: identify different users
    id="msg_123", 
 ) # Optional: unique identifier for tracing

response = model.invoke([
  human_msg
])
response
# Out:
# AIMessage(content='Hello. How can I help you today?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 37, 'total_tokens': 47, 'completion_time': 0.02882609, 'completion_tokens_details': None, 'prompt_time': 0.003207224, 'prompt_tokens_details': None, 'queue_time': 0.05633923, 'total_time': 0.032033314}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a000a3-361e-7322-a1be-7bf6fc92fd72-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 37, 'output_tokens': 10, 'total_tokens': 47})

# %%
from langchain.messages import AIMessage, SystemMessage, HumanMessage

ai_msg = AIMessage("I'd be happy to help you with that question!")

messages = [
    SystemMessage("You are a helpful assistant"),
    HumanMessage("Can you help me?"),
    ai_msg,  # Insert as if it came from the model
    HumanMessage("Great! What's 2+2?")
]

response = model.invoke(messages)
print(response.content)
# Out:
# That's an easy one. The answer is 4! Do you have any more questions or is there something else I can help you with?

# %%
response.usage_metadata
# Out:
# {'input_tokens': 75, 'output_tokens': 30, 'total_tokens': 105}

# %%
from langchain.messages import ToolMessage, AIMessage

# After a model makes a tool call
# (Here, we demonstrate manually creating the messages for brevity)
ai_message = AIMessage(
    content=[],
    tool_calls=[{
        "name": "get_weather",
        "args": {"location": "San Francisco"},
        "id": "call_123"
    }]
)

# Execute tool and create result message
weather_result = "Sunny, 72°F"
tool_message = ToolMessage(
    content=weather_result,
    tool_call_id="call_123"  # Must match the call ID
)
messages = [
    HumanMessage("What's the weather in San Francisco?"),
    ai_message,  # Model's tool call
    tool_message,  # Tool execution result
]
response = model.invoke(messages)

# %%
tool_message
# Out:
# ToolMessage(content='Sunny, 72°F', tool_call_id='call_123')

# %%
response
# Out:
# AIMessage(content="It's sunny and 72°F in San Francisco. Would you like more information about the weather forecast or any specific details?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 74, 'total_tokens': 100, 'completion_time': 0.13625059, 'completion_tokens_details': None, 'prompt_time': 0.006914024, 'prompt_tokens_details': None, 'queue_time': 0.165072499, 'total_time': 0.143164614}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a000a6-9876-7831-b0d4-302425ef178a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 74, 'output_tokens': 26, 'total_tokens': 100})
